# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori,association_rules
df1=pd.read_csv('Dataset.csv')
df2=pd.read_csv('Movie_Id_Titles.csv')

# %%
df1.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %%
df2.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
df1.isnull().sum()
# Out:
# user_id      0
# item_id      0
# rating       0
# timestamp    0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# item_id    0
# title      0
# dtype: int64

# %%
df1=df1.drop(['timestamp'],axis='columns')
df1.head()
# Out:
#    user_id  item_id  rating
# 0        0       50       5
# 1        0      172       5
# 2        0      133       1
# 3      196      242       3
# 4      186      302       3

# %%
df=pd.merge(df1,df2,left_on='item_id',right_on='item_id')
df
# Out:
#         user_id  item_id  rating  \
# 0             0       50       5
# 1           290       50       5
# 2            79       50       4
# 3             2       50       5
# 4             8       50       5
# ...         ...      ...     ...
# 99998       840     1674       4
# 99999       655     1640       3
# 100000      655     1637       3
# 100001      655     1630       3
# 100002      655     1641       3
#
#                                                     title
# 0                                        Star Wars (1977)
# 1                                        Star Wars (1977)
# 2                                        Star Wars (1977)
# 3                                        Star Wars (1977)
# 4                                        Star Wars (1977)
# ...                                                   ...
# 99998                                   Mamma Roma (1962)
# 99999                              Eighth Day, The (1996)
# 100000                                  Girls Town (1996)
# 100001  Silence of the Palace, The (Saimt el Qusur) (1...
# 100002                                    Dadetown (1995)
#
# [100003 rows x 4 columns]

# %%
df['item_id'].nunique()
# Out:
# 1682

# %%
df['user_id'].nunique()
# Out:
# 944

# %%
df['title'].nunique()
# Out:
# 1664

# %%
df['rating'].unique()
# Out:
# array([5, 4, 2, 3, 1], dtype=int64)

# %%
def convert_rating(rating):
    if rating >= 4:
        return 1
    else:
        return 0

# %%
mov_list=df.groupby(['user_id','title'])['rating'].sum().unstack().reset_index().fillna(0).set_index("user_id")

# %%
from mlxtend.frequent_patterns import apriori,association_rules

# %%
mov_list = mov_list.applymap(convert_rating)

# %%
frequent_movi = apriori(mov_list , use_colnames=True ,min_support=0.08)
frequent_movi
# Out:
# C:\Users\a4abh\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#         support                                           itemsets
# 0      0.115466                              (12 Angry Men (1957))
# 1      0.198093                     (2001: A Space Odyssey (1968))
# 2      0.090042                                (Abyss, The (1989))
# 3      0.131356                        (African Queen, The (1951))
# 4      0.266949                             (Air Force One (1997))
# ...         ...                                                ...
# 14256  0.080508  (Raiders of the Lost Ark (1981), Star Wars (19...
# 14257  0.081568  (Silence of the Lambs, The (1991), Raiders of ...
# 14258  0.080508  (Raiders of the Lost Ark (1981), Star Wars (19...
# 14259  0.082627  (Raiders of the Lost Ark (1981), Star Wars (19...
# 14260  0.080508  (Silence of the Lambs, The (1991), Raiders of ...
#
# [14261 rows x 2 columns]

# %%
result = association_rules(frequent_movi , metric='lift' , min_threshold=1)
result
# Out:
#                                 antecedents  \
# 0                     (12 Angry Men (1957))
# 1          (Raiders of the Lost Ark (1981))
# 2                     (12 Angry Men (1957))
# 3        (Silence of the Lambs, The (1991))
# 4                     (12 Angry Men (1957))
# ...                                     ...
# 166889                   (Star Wars (1977))
# 166890    (Empire Strikes Back, The (1980))
# 166891          (Return of the Jedi (1983))
# 166892             (Terminator, The (1984))
# 166893  (Terminator 2: Judgment Day (1991))
#
#                                               consequents  antecedent support  \
# 0                        (Raiders of the Lost Ark (1981))            0.115466
# 1                                   (12 Angry Men (1957))            0.368644
# 2                      (Silence of the Lambs, The (1991))            0.115466
# 3                                   (12 Angry Men (1957))            0.364407
# 4                                      (Star Wars (1977))            0.115466
# ...                                                   ...                 ...
# 166889  (Silence of the Lambs, The (1991), Raiders of ...            0.531780
# 166890  (Silence of the Lambs, The (1991), Raiders of ...            0.311441
# 166891  (Silence of the Lambs, The (1991), Raiders of ...            0.401483
# 166892  (Silence of the Lambs, The (1991), Raiders of ...            0.229873
# 166893  (Silence of the Lambs, The (1991), Raiders of ...            0.239407
#
#         consequent support   support  confidence      lift  leverage  \
# 0                 0.368644  0.080508    0.697248  1.891385  0.037943
# 1                 0.115466  0.080508    0.218391  1.891385  0.037943
# 2                 0.364407  0.082627    0.715596  1.963729  0.040550
# 3                 0.115466  0.082627    0.226744  1.963729  0.040550
# 4                 0.531780  0.092161    0.798165  1.500932  0.030758
# ...                    ...       ...         ...       ...       ...
# 166889            0.082627  0.080508    0.151394  1.832261  0.036569
# 166890            0.085805  0.080508    0.258503  3.012682  0.053785
# 166891            0.095339  0.080508    0.200528  2.103313  0.042231
# 166892            0.087924  0.080508    0.350230  3.983344  0.060297
# 166893            0.100636  0.080508    0.336283  3.341593  0.056416
#
#         conviction  zhangs_metric
# 0         2.085388       0.532808
# 1         1.131683       0.746468
# 2         2.234828       0.554829
# 3         1.143909       0.772137
# 4         2.319819       0.377314
# ...            ...            ...
# 166889    1.081036       0.970112
# 166890    1.232905       0.970243
# 166891    1.131573       0.876432
# 166892    1.403692       0.972508
# 166893    1.355042       0.921309
#
# [166894 rows x 10 columns]

# %%
fin_result=result[['antecedents','consequents','support','confidence','lift','leverage']]
fin_result
# Out:
#                                 antecedents  \
# 0                     (12 Angry Men (1957))
# 1          (Raiders of the Lost Ark (1981))
# 2                     (12 Angry Men (1957))
# 3        (Silence of the Lambs, The (1991))
# 4                     (12 Angry Men (1957))
# ...                                     ...
# 166889                   (Star Wars (1977))
# 166890    (Empire Strikes Back, The (1980))
# 166891          (Return of the Jedi (1983))
# 166892             (Terminator, The (1984))
# 166893  (Terminator 2: Judgment Day (1991))
#
#                                               consequents   support  \
# 0                        (Raiders of the Lost Ark (1981))  0.080508
# 1                                   (12 Angry Men (1957))  0.080508
# 2                      (Silence of the Lambs, The (1991))  0.082627
# 3                                   (12 Angry Men (1957))  0.082627
# 4                                      (Star Wars (1977))  0.092161
# ...                                                   ...       ...
# 166889  (Silence of the Lambs, The (1991), Raiders of ...  0.080508
# 166890  (Silence of the Lambs, The (1991), Raiders of ...  0.080508
# 166891  (Silence of the Lambs, The (1991), Raiders of ...  0.080508
# 166892  (Silence of the Lambs, The (1991), Raiders of ...  0.080508
# 166893  (Silence of the Lambs, The (1991), Raiders of ...  0.080508
#
#         confidence      lift  leverage
# 0         0.697248  1.891385  0.037943
# 1         0.218391  1.891385  0.037943
# 2         0.715596  1.963729  0.040550
# 3         0.226744  1.963729  0.040550
# 4         0.798165  1.500932  0.030758
# ...            ...       ...       ...
# 166889    0.151394  1.832261  0.036569
# 166890    0.258503  3.012682  0.053785
# 166891    0.200528  2.103313  0.042231
# 166892    0.350230  3.983344  0.060297
# 166893    0.336283  3.341593  0.056416
#
# [166894 rows x 6 columns]

# %%
pred_1=association_rules(frequent_movi,metric='support',min_threshold=0.05)
pred_1
# Out:
#                                 antecedents  \
# 0                     (12 Angry Men (1957))
# 1          (Raiders of the Lost Ark (1981))
# 2                     (12 Angry Men (1957))
# 3        (Silence of the Lambs, The (1991))
# 4                     (12 Angry Men (1957))
# ...                                     ...
# 166953                   (Star Wars (1977))
# 166954    (Empire Strikes Back, The (1980))
# 166955          (Return of the Jedi (1983))
# 166956             (Terminator, The (1984))
# 166957  (Terminator 2: Judgment Day (1991))
#
#                                               consequents  antecedent support  \
# 0                        (Raiders of the Lost Ark (1981))            0.115466
# 1                                   (12 Angry Men (1957))            0.368644
# 2                      (Silence of the Lambs, The (1991))            0.115466
# 3                                   (12 Angry Men (1957))            0.364407
# 4                                      (Star Wars (1977))            0.115466
# ...                                                   ...                 ...
# 166953  (Silence of the Lambs, The (1991), Raiders of ...            0.531780
# 166954  (Silence of the Lambs, The (1991), Raiders of ...            0.311441
# 166955  (Silence of the Lambs, The (1991), Raiders of ...            0.401483
# 166956  (Silence of the Lambs, The (1991), Raiders of ...            0.229873
# 166957  (Silence of the Lambs, The (1991), Raiders of ...            0.239407
#
#         consequent support   support  confidence      lift  leverage  \
# 0                 0.368644  0.080508    0.697248  1.891385  0.037943
# 1                 0.115466  0.080508    0.218391  1.891385  0.037943
# 2                 0.364407  0.082627    0.715596  1.963729  0.040550
# 3                 0.115466  0.082627    0.226744  1.963729  0.040550
# 4                 0.531780  0.092161    0.798165  1.500932  0.030758
# ...                    ...       ...         ...       ...       ...
# 166953            0.082627  0.080508    0.151394  1.832261  0.036569
# 166954            0.085805  0.080508    0.258503  3.012682  0.053785
# 166955            0.095339  0.080508    0.200528  2.103313  0.042231
# 166956            0.087924  0.080508    0.350230  3.983344  0.060297
# 166957            0.100636  0.080508    0.336283  3.341593  0.056416
#
#         conviction  zhangs_metric
# 0         2.085388       0.532808
# 1         1.131683       0.746468
# 2         2.234828       0.554829
# 3         1.143909       0.772137
# 4         2.319819       0.377314
# ...            ...            ...
# 166953    1.081036       0.970112
# 166954    1.232905       0.970243
# 166955    1.131573       0.876432
# 166956    1.403692       0.972508
# 166957    1.355042       0.921309
#
# [166958 rows x 10 columns]

# %%
pred_1[['antecedents','consequents','support','confidence','lift','leverage']].to_csv('pred_1_invoice.csv')

# %%
dfr=pd.read_csv('pred_1_invoice.csv',index_col=0)
dfr
# Out:
#                                              antecedents  \
# 0                     frozenset({'12 Angry Men (1957)'})
# 1          frozenset({'Raiders of the Lost Ark (1981)'})
# 2                     frozenset({'12 Angry Men (1957)'})
# 3        frozenset({'Silence of the Lambs, The (1991)'})
# 4                     frozenset({'12 Angry Men (1957)'})
# ...                                                  ...
# 166953                   frozenset({'Star Wars (1977)'})
# 166954    frozenset({'Empire Strikes Back, The (1980)'})
# 166955          frozenset({'Return of the Jedi (1983)'})
# 166956             frozenset({'Terminator, The (1984)'})
# 166957  frozenset({'Terminator 2: Judgment Day (1991)'})
#
#                                               consequents   support  \
# 0           frozenset({'Raiders of the Lost Ark (1981)'})  0.080508
# 1                      frozenset({'12 Angry Men (1957)'})  0.080508
# 2         frozenset({'Silence of the Lambs, The (1991)'})  0.082627
# 3                      frozenset({'12 Angry Men (1957)'})  0.082627
# 4                         frozenset({'Star Wars (1977)'})  0.092161
# ...                                                   ...       ...
# 166953  frozenset({'Silence of the Lambs, The (1991)',...  0.080508
# 166954  frozenset({'Silence of the Lambs, The (1991)',...  0.080508
# 166955  frozenset({'Silence of the Lambs, The (1991)',...  0.080508
# 166956  frozenset({'Silence of the Lambs, The (1991)',...  0.080508
# 166957  frozenset({'Silence of the Lambs, The (1991)',...  0.080508
#
#         confidence      lift  leverage
# 0         0.697248  1.891385  0.037943
# 1         0.218391  1.891385  0.037943
# 2         0.715596  1.963729  0.040550
# 3         0.226744  1.963729  0.040550
# 4         0.798165  1.500932  0.030758
# ...            ...       ...       ...
# 166953    0.151394  1.832261  0.036569
# 166954    0.258503  3.012682  0.053785
# 166955    0.200528  2.103313  0.042231
# 166956    0.350230  3.983344  0.060297
# 166957    0.336283  3.341593  0.056416
#
# [166958 rows x 6 columns]

# %%
dfr['antecedents']=dfr['antecedents'].str.replace('frozenset','')
dfr['consequents']=dfr['consequents'].str.replace('frozenset','')

# %%
dfr.head()
# Out:
#                               antecedents  \
# 0               ({'12 Angry Men (1957)'})
# 1    ({'Raiders of the Lost Ark (1981)'})
# 2               ({'12 Angry Men (1957)'})
# 3  ({'Silence of the Lambs, The (1991)'})
# 4               ({'12 Angry Men (1957)'})
#
#                               consequents   support  confidence      lift  \
# 0    ({'Raiders of the Lost Ark (1981)'})  0.080508    0.697248  1.891385
# 1               ({'12 Angry Men (1957)'})  0.080508    0.218391  1.891385
# 2  ({'Silence of the Lambs, The (1991)'})  0.082627    0.715596  1.963729
# 3               ({'12 Angry Men (1957)'})  0.082627    0.226744  1.963729
# 4                  ({'Star Wars (1977)'})  0.092161    0.798165  1.500932
#
#    leverage
# 0  0.037943
# 1  0.037943
# 2  0.040550
# 3  0.040550
# 4  0.030758

# %%
title="({'Star Wars (1977)'})"
dfr[dfr['antecedents']==title]
# Out:
#                    antecedents  \
# 5       ({'Star Wars (1977)'})
# 82      ({'Star Wars (1977)'})
# 114     ({'Star Wars (1977)'})
# 143     ({'Star Wars (1977)'})
# 189     ({'Star Wars (1977)'})
# ...                        ...
# 166448  ({'Star Wars (1977)'})
# 166575  ({'Star Wars (1977)'})
# 166700  ({'Star Wars (1977)'})
# 166826  ({'Star Wars (1977)'})
# 166953  ({'Star Wars (1977)'})
#
#                                               consequents   support  \
# 5                               ({'12 Angry Men (1957)'})  0.092161
# 82                     ({'2001: A Space Odyssey (1968)'})  0.154661
# 114                       ({'African Queen, The (1951)'})  0.109110
# 143                            ({'Air Force One (1997)'})  0.128178
# 189                                  ({'Aladdin (1992)'})  0.126059
# ...                                                   ...       ...
# 166448  ({'Raiders of the Lost Ark (1981)', 'Empire St...  0.080508
# 166575  ({'Silence of the Lambs, The (1991)', 'Raiders...  0.081568
# 166700  ({'Raiders of the Lost Ark (1981)', 'Empire St...  0.080508
# 166826  ({'Raiders of the Lost Ark (1981)', 'Empire St...  0.082627
# 166953  ({'Silence of the Lambs, The (1991)', 'Raiders...  0.080508
#
#         confidence      lift  leverage
# 5         0.173307  1.500932  0.030758
# 82        0.290837  1.468181  0.049319
# 114       0.205179  1.562010  0.039258
# 143       0.241036  0.902928 -0.013780
# 189       0.237052  1.554006  0.044940
# ...            ...       ...       ...
# 166448    0.151394  1.856056  0.037132
# 166575    0.153386  1.880478  0.038192
# 166700    0.151394  1.856056  0.037132
# 166826    0.155378  1.856675  0.038124
# 166953    0.151394  1.832261  0.036569
#
# [5329 rows x 6 columns]

# %%
print(dfr[dfr['consequents'] == title].antecedents)
# Out:
# 4                                 ({'12 Angry Men (1957)'})
# 83                       ({'2001: A Space Odyssey (1968)'})
# 115                         ({'African Queen, The (1951)'})
# 142                              ({'Air Force One (1997)'})
# 188                                    ({'Aladdin (1992)'})
#                                 ...
# 166333    ({'Raiders of the Lost Ark (1981)', 'Empire St...
# 166458    ({'Silence of the Lambs, The (1991)', 'Raiders...
# 166585    ({'Raiders of the Lost Ark (1981)', 'Empire St...
# 166711    ({'Raiders of the Lost Ark (1981)', 'Empire St...
# 166836    ({'Silence of the Lambs, The (1991)', 'Raiders...
# Name: antecedents, Length: 5329, dtype: object
